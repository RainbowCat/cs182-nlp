# %% [markdown]
# # SETUP

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
from pathlib import Path

ROOT_FOLDER = Path("/content/drive/My Drive/cs182_final_project/cs182-nlp")
DATA_FOLDER = ROOT_FOLDER / "dataset"
sys.path.insert(0, str(ROOT_FOLDER))

# %%
sys.path
# Out:
# ['/content/drive/My Drive/cs182_final_project/cs182-nlp',
#  '',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %% [markdown]
# ## Install

# %%
# !pip install -r "/content/drive/My Drive/cs182_final_project/cs182-nlp/requirements.txt"
# Out:
# ...
#      |████████████████████████████████| 1.3MB 4.2MB/s
# ...
#      |████████████████████████████████| 61kB 6.1MB/s
# ...
#      |████████████████████████████████| 133kB 40.3MB/s
# ...
#      |████████████████████████████████| 184kB 39.7MB/s
# ...
#      |████████████████████████████████| 112kB 40.8MB/s
# ...
#      |████████████████████████████████| 829kB 35.2MB/s
# ...
#      |████████████████████████████████| 153kB 29.4MB/s
# ...
#      |████████████████████████████████| 4.2MB 39.3MB/s
# ...
#      |████████████████████████████████| 4.1MB 17.7MB/s
# ...
#      |████████████████████████████████| 122kB 46.7MB/s
# ...
#      |████████████████████████████████| 788kB 37.0MB/s
# ...
#      |████████████████████████████████| 61kB 8.0MB/s
# ...
#      |████████████████████████████████| 122kB 46.2MB/s
# ...
#      |████████████████████████████████| 10.3MB 24.7MB/s
# ...
#      |████████████████████████████████| 143kB 53.6MB/s
# ...
#      |████████████████████████████████| 552kB 34.5MB/s
# ...
#      |████████████████████████████████| 1.5MB 40.8MB/s
# ...

# %% [markdown]
# ## Imports

# %%
import os
import sys
from pathlib import Path

import json
import pandas as pd
import random


import tqdm

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

import huggingface_hub

import pickle

import pytorch_lightning as pl
# Out:
# [autoreload of IPython.core.debugger failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     del self.failed[py_filename]
# ValueError: wrapper() requires a code object with 1 free vars, not 0
# ]
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7fbdc0508d50>> (for post_execute):

# %%
import data
import models

# %% [markdown]
# # PICK ARGUMENTS

# %%
from argparse import Namespace

args = Namespace(
    use_bert = True,
    use_vader = True,
    batch_size = 240,
    epochs = 10,
    max_len = 128,
    max_len_vader = 128,
)
# Out:
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7fbdc0508d50>> (for post_execute):

# %%
# if args.use_bert:
#   dataset_name = "dataset/xlnet-tokens.pkl"
# else:
#   dataset_name = "dataset/bert-tokens.pkl"
# Out:
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7fbdc0508d50>> (for post_execute):

# %% [markdown]
# # RUN

# %%
import json
data.YelpDataModule(args)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /content/drive/My Drive/cs182_final_project/cs182-nlp/data.py in __init__(self, args, data_path)
#     113         try:
# --> 114             with open(PRECOMPUTED_DATA, "rb") as f:
#     115                 self.dataset = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bert-tokens.pkl'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c661cf36083c> in <module>
#       1 import json
# ----> 2 data.YelpDataModule(args)
#
# /content/drive/My Drive/cs182_final_project/cs182-nlp/data.py in __init__(self, args, data_path)
#     115                 self.dataset = pickle.load(f)
#     116         except FileNotFoundError:
# --> 117             self.dataset = YelpDataset(args, data_path)
# ...
